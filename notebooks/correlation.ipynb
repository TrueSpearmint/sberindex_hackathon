# %%
# %pip install pysal
# %pip install contextily
# Out:
# Requirement already satisfied: pysal in c:\users\ghena\appdata\roaming\python\python310\site-packages (24.1)
# Requirement already satisfied: libpysal>=4.6.2 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (4.10)
# Requirement already satisfied: access>=1.1.8 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (1.1.9)
# Requirement already satisfied: esda>=2.4.1 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (2.5.1)
# Requirement already satisfied: giddy>=2.3.3 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (2.3.5)
# Requirement already satisfied: inequality>=1.0.0 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (1.0.1)
# Requirement already satisfied: pointpats>=2.2.0 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (2.4.0)
# Requirement already satisfied: segregation>=2.3.1 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (2.5)
# Requirement already satisfied: spaghetti>=1.6.6 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (1.7.5.post1)
# Requirement already satisfied: mgwr>=2.1.2 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (2.2.1)
# Requirement already satisfied: momepy>=0.5.3 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (0.7.0)
# Requirement already satisfied: spglm>=1.0.8 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (1.1.0)
# Requirement already satisfied: spint>=1.0.7 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (1.0.7)
# Requirement already satisfied: spreg>=1.2.4 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (1.4.2)
# Requirement already satisfied: spvcm>=0.3.0 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (0.3.0)
# Requirement already satisfied: tobler>=0.8.2 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (0.11.2)
# Requirement already satisfied: mapclassify>=2.4.3 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (2.6.1)
# Requirement already satisfied: splot>=1.1.5.post1 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (1.1.5.post1)
# Requirement already satisfied: spopt>=0.4.1 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from pysal) (0.6.0)
# Requirement already satisfied: geopandas in c:\users\ghena\appdata\roaming\python\python310\site-packages (from access>=1.1.8->pysal) (0.14.3)
# Requirement already satisfied: numpy>=1.3 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from access>=1.1.8->pysal) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from access>=1.1.8->pysal) (1.5.3)
# Requirement already satisfied: requests>=2 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from access>=1.1.8->pysal) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from esda>=2.4.1->pysal) (1.4.1.post1)
# Requirement already satisfied: scipy>=1.9 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from esda>=2.4.1->pysal) (1.11.3)
# Requirement already satisfied: quantecon>=0.4.7 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from giddy>=2.3.3->pysal) (0.7.2)
# Requirement already satisfied: beautifulsoup4>=4.10 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from libpysal>=4.6.2->pysal) (4.12.3)
# Requirement already satisfied: packaging>=22 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from libpysal>=4.6.2->pysal) (23.0)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from libpysal>=4.6.2->pysal) (3.0.0)
# Requirement already satisfied: shapely>=2.0.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from libpysal>=4.6.2->pysal) (2.1.1)
# Requirement already satisfied: networkx>=2.7 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from mapclassify>=2.4.3->pysal) (3.2.1)
# Requirement already satisfied: tqdm>=4.63.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from momepy>=0.5.3->pysal) (4.66.2)
# Requirement already satisfied: matplotlib in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pointpats>=2.2.0->pysal) (3.7.1)
# Requirement already satisfied: deprecation in c:\users\ghena\appdata\roaming\python\python310\site-packages (from segregation>=2.3.1->pysal) (2.1.0)
# Requirement already satisfied: joblib in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from segregation>=2.3.1->pysal) (1.3.2)
# Requirement already satisfied: seaborn in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from segregation>=2.3.1->pysal) (0.13.2)
# Requirement already satisfied: numba in c:\users\ghena\appdata\roaming\python\python310\site-packages (from segregation>=2.3.1->pysal) (0.59.1)
# Requirement already satisfied: pyproj>=3 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from segregation>=2.3.1->pysal) (3.4.1)
# Requirement already satisfied: rtree>=1.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from spaghetti>=1.6.6->pysal) (1.2.0)
# Requirement already satisfied: pulp>=2.7 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from spopt>=0.4.1->pysal) (2.8.0)
# Requirement already satisfied: rasterio in c:\users\ghena\appdata\roaming\python\python310\site-packages (from tobler>=0.8.2->pysal) (1.3.10)
# Requirement already satisfied: statsmodels in c:\users\ghena\appdata\roaming\python\python310\site-packages (from tobler>=0.8.2->pysal) (0.14.1)
# Requirement already satisfied: rasterstats in c:\users\ghena\appdata\roaming\python\python310\site-packages (from tobler>=0.8.2->pysal) (0.19.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.10->libpysal>=4.6.2->pysal) (2.5)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from geopandas->access>=1.1.8->pysal) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->access>=1.1.8->pysal) (2022.7.1)
# Requirement already satisfied: certifi in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pyproj>=3->segregation>=2.3.1->pysal) (2022.12.7)
# Requirement already satisfied: sympy in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.12)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from numba->segregation>=2.3.1->pysal) (0.42.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from requests>=2->access>=1.1.8->pysal) (1.26.18)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=1.0->esda>=2.4.1->pysal) (3.3.0)
# Requirement already satisfied: colorama in c:\users\ghena\appdata\roaming\python\python310\site-packages (from tqdm>=4.63.0->momepy>=0.5.3->pysal) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pointpats>=2.2.0->pysal) (3.0.9)
# Requirement already satisfied: affine in c:\users\ghena\appdata\roaming\python\python310\site-packages (from rasterio->tobler>=0.8.2->pysal) (2.4.0)
# Requirement already satisfied: attrs in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (22.2.0)
# Requirement already satisfied: click>=4.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (8.1.3)
# Requirement already satisfied: cligj>=0.5 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->tobler>=0.8.2->pysal) (65.5.0)
# Requirement already satisfied: simplejson in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterstats->tobler>=0.8.2->pysal) (3.19.2)
# Requirement already satisfied: patsy>=0.5.4 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from statsmodels->tobler>=0.8.2->pysal) (0.5.6)
# Requirement already satisfied: munch>=2.3.2 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from fiona>=1.8.21->geopandas->access>=1.1.8->pysal) (2.5.0)
# Requirement already satisfied: six in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from patsy>=0.5.4->statsmodels->tobler>=0.8.2->pysal) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from sympy->quantecon>=0.4.7->giddy>=2.3.3->pysal) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: contextily in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (1.6.2)
# Requirement already satisfied: geopy in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from contextily) (3.7.1)
# Requirement already satisfied: mercantile in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from contextily) (10.2.0)
# Requirement already satisfied: rasterio in c:\users\ghena\appdata\roaming\python\python310\site-packages (from contextily) (1.3.10)
# Requirement already satisfied: requests in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from contextily) (2.31.0)
# Requirement already satisfied: joblib in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from contextily) (1.3.2)
# Requirement already satisfied: xyzservices in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from contextily) (2024.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->contextily) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->contextily) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->contextily) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->contextily) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from matplotlib->contextily) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->contextily) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from mercantile->contextily) (8.1.3)
# Requirement already satisfied: affine in c:\users\ghena\appdata\roaming\python\python310\site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->contextily) (22.2.0)
# Requirement already satisfied: certifi in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->contextily) (2022.12.7)
# Requirement already satisfied: cligj>=0.5 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from rasterio->contextily) (65.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from requests->contextily) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from requests->contextily) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from requests->contextily) (1.26.18)
# Requirement already satisfied: colorama in c:\users\ghena\appdata\roaming\python\python310\site-packages (from click>=3.0->mercantile->contextily) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib
# %pip install geopandas
# %pip install pandas
# Out:
# Requirement already satisfied: matplotlib in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghena\appdata\roaming\python\python310\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: geopandas in c:\users\ghena\appdata\roaming\python\python310\site-packages (0.14.3)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from geopandas) (1.9.1)
# Requirement already satisfied: packaging in c:\users\ghena\appdata\roaming\python\python310\site-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from geopandas) (3.4.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from fiona>=1.8.21->geopandas) (22.2.0)
# Requirement already satisfied: certifi in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from fiona>=1.8.21->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from fiona>=1.8.21->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: munch>=2.3.2 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from fiona>=1.8.21->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from fiona>=1.8.21->geopandas) (65.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.4.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.4.0->geopandas) (1.26.4)
# Requirement already satisfied: colorama in c:\users\ghena\appdata\roaming\python\python310\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: six in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from munch>=2.3.2->fiona>=1.8.21->geopandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: six>=1.5 in c:\users\ghena\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Графика
import matplotlib.pyplot as plt
import seaborn
from pysal.viz import splot
from splot.esda import plot_moran
import contextily as ctx

# Анализ
import geopandas as gpd
import pandas as pd
from pysal.explore import esda
from pysal.lib import weights
from numpy.random import seed

# %%
# данные

# %% [markdown]
# ## План показателей
# ### Доход и потребление
# #### Среднедушевой доход населения по МО (или медианный доход)
# #### Объём потребительских расходов (по SberIndex)
# #### Коэффициент самообеспеченности (доля товаров и услуг, производимых и потребляемых внутри МО) — если можно оценить
#
# ### Доступность инфраструктуры
# #### Плотность дорожной сети и/или расстояние до ближайшего транспортного узла
# #### Доля населения, имеющая доступ к объектам образования, медицины и торговли (в пределах 30 минут на транспорте)
#
# ### Демография и занятость
# #### Уровень безработицы
# #### Численность и плотность населения
# #### Миграционный прирост/убыль
# #### Возрастная структура (доля трудоспособного населения)
#
# ### Финансовые показатели МО
# #### Доходы местных бюджетов на душу населения
# #### Доля трансфертов от федерального/регионального бюджета
# #### Расходы бюджета на социальные нужды (на душу)
#
# ### ГЕО
# #### Геометрии муниципальных образований
# #### Соседства (матрица весов W) — можно вычислить из геометрии
# #### Расстояния между центрами МО или их гравитационными центрами

# %% [markdown]
# ## Baseline

# %%
# baseline доходы, расходы, половозростайка потом Глобальный индекс Moran’s I: 0.426, p-value: 0.001
import geopandas as gpd
import pandas as pd

# Загрузка данных
gdf_spending = gpd.read_file("gdf_consumption_for_2023_2024.gpkg")
gdf_salary = gpd.read_file("gdf_salary_for_2023_2024.gpkg")

gdf_spending = gdf_spending
gdf_salary = gdf_salary

# Проверим, что общие ключи совпадают
assert set(gdf_spending["territory_id"]) == set(gdf_salary["territory_id"]), "Несовпадение МО!"

# Объединение по идентификатору территории
gdf_merged = gdf_spending.merge(
    gdf_salary[["territory_id", "mean_salary_for_2023_2024"]],
    on="territory_id"
)

# Вычисляем базовую метрику
gdf_merged["spending_to_salary_ratio"] = (
    gdf_merged["mean_spending_for_2023_2024"] /
    gdf_merged["mean_salary_for_2023_2024"]
)

# %%
# бюджетная обеспеченность по регионам
df_budget = pd.read_excel("Уровень_бюджетной_обеспеченности_Таблица_2025_06_07.xlsx")

df_budget_cleaned = df_budget.copy()
df_budget_cleaned = df_budget_cleaned[df_budget_cleaned["Субъекты Российской Федерации"].notna()]
df_budget_cleaned = df_budget_cleaned[~df_budget_cleaned["Субъекты Российской Федерации"].str.contains("федеральный округ", case=False, na=False)]
df_budget_cleaned = df_budget_cleaned[~df_budget_cleaned["Субъекты Российской Федерации"].str.contains("Уровень", na=False)]

# Переименуем колонку для удобства
df_budget_cleaned = df_budget_cleaned.rename(columns={
    "Субъекты Российской Федерации": "region_name",
    "2024 год": "budget_before_dots_2024",
    "2024 год.1": "budget_after_dots_2024"
})

# Приводим названия регионов к строковому формату и убираем пробелы
df_budget_cleaned["region_name"] = df_budget_cleaned["region_name"].str.strip()
gdf_merged["region_name"] = gdf_merged["region_name"].str.strip()

# Объединяем по названию региона
gdf_merged = gdf_merged.merge(df_budget_cleaned[["region_name", "budget_before_dots_2024", "budget_after_dots_2024"]],
                              on="region_name", how="left")

# %%
# Удаляем строки с NaN в столбце отношения расходов к доходу
gdf_clean = gdf_merged.dropna(subset=["spending_to_salary_ratio"]).copy()

# Проверим размерность после очистки
print(f"Осталось наблюдений: {len(gdf_clean)}")
# Out:
# Осталось наблюдений: 2170

# %%
from libpysal.weights import Queen
from esda.moran import Moran, Moran_Local

# Создание весов по смежности
w = Queen.from_dataframe(gdf_clean)
w.transform = 'r'

# Глобальная автокорреляция
moran = Moran(gdf_clean["spending_to_salary_ratio"], w)
print(f"Глобальный индекс Moran’s I: {moran.I:.3f}, p-value: {moran.p_sim:.3f}")
# Out:
# C:\Users\ghena\AppData\Local\Temp\ipykernel_12604\3089960727.py:5: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w = Queen.from_dataframe(gdf_clean)
# ('WARNING: ', 50, ' is an island (no neighbors)')
# ('WARNING: ', 74, ' is an island (no neighbors)')
# ('WARNING: ', 75, ' is an island (no neighbors)')
# ('WARNING: ', 79, ' is an island (no neighbors)')
# ('WARNING: ', 80, ' is an island (no neighbors)')
# ('WARNING: ', 81, ' is an island (no neighbors)')
# ('WARNING: ', 341, ' is an island (no neighbors)')
# ('WARNING: ', 388, ' is an island (no neighbors)')
# ('WARNING: ', 662, ' is an island (no neighbors)')
# ('WARNING: ', 726, ' is an island (no neighbors)')
# ('WARNING: ', 881, ' is an island (no neighbors)')
# ('WARNING: ', 908, ' is an island (no neighbors)')
# ('WARNING: ', 1074, ' is an island (no neighbors)')
# ('WARNING: ', 1526, ' is an island (no neighbors)')
# ('WARNING: ', 1602, ' is an island (no neighbors)')
# ('WARNING: ', 1664, ' is an island (no neighbors)')
# ('WARNING: ', 1700, ' is an island (no neighbors)')
# ('WARNING: ', 1809, ' is an island (no neighbors)')
# Глобальный индекс Moran’s I: 0.455, p-value: 0.001
# C:\Users\ghena\AppData\Roaming\Python\Python310\site-packages\libpysal\weights\contiguity.py:347: UserWarning: The weights matrix is not fully connected:
#  There are 23 disconnected components.
#  There are 18 islands with ids: 50, 74, 75, 79, 80, 81, 341, 388, 662, 726, 881, 908, 1074, 1526, 1602, 1664, 1700, 1809.
#   W.__init__(self, neighbors, ids=ids, **kw)

# %%
lisa = Moran_Local(gdf_clean["spending_to_salary_ratio"], w)

# Добавим результаты обратно в GeoDataFrame
gdf_clean["lisa_cluster"] = lisa.q  # 1=HH, 2=LH, 3=LL, 4=HL
gdf_clean["lisa_significant"] = lisa.p_sim < 0.05

# %%
import matplotlib.pyplot as plt
import numpy as np
from splot.esda import moran_scatterplot

# Строим диаграмму Морана
fig, ax = moran_scatterplot(lisa, aspect_equal=True)
ax.set_title("Диаграмма рассеяния Морана", fontsize=14)

# Настроим линии деления на квадранты
mean_x = 0
mean_y = 0
ax.axhline(mean_y, color='k', linestyle='--')
ax.axvline(mean_x, color='k', linestyle='--')

# Подписи квадрантов
ax.text(1.5, 1.5, 'High-High', color='green', fontsize=12)
ax.text(-1.5, 1.5, 'Low-High', color='orange', fontsize=12)
ax.text(-1.5, -1.5, 'Low-Low', color='blue', fontsize=12)
ax.text(1.5, -1.5, 'High-Low', color='red', fontsize=12)

plt.show()

# %% [markdown]
# | Квадрант  | Интерпретация                                       |
# | --------- | --------------------------------------------------- |
# | High-High | Высокое значение и у объекта, и у соседей (кластер) |
# | Low-Low   | Низкое значение и у объекта, и у соседей (кластер)  |
# | High-Low  | Высокое значение у объекта, но низкое у соседей     |
# | Low-High  | Низкое значение у объекта, но высокое у соседей     |

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
gdf_clean.assign(cluster_label=gdf_clean["lisa_cluster"].map({
    1: "High-High", 2: "Low-High", 3: "Low-Low", 4: "High-Low"
})).plot(
    column="cluster_label",
    categorical=True,
    legend=True,
    ax=ax,
    edgecolor="black"
)
plt.title("LISA-карта по показателю расходов к доходу")
plt.show()

# %%
# Сохраняем результаты
gdf_clean.to_file("lisa_results_spending_to_salary_expences.gpkg", driver="gpkg")
gdf_merged.to_file("gdf_merged_region_losses.gpkg", driver="gpkg")

# %%
import matplotlib.pyplot as plt
from libpysal.weights import Queen
from libpysal.weights import lag_spatial


# === Шаг 1: Подготовка данных ===
gdf_clean = gdf_merged.dropna(subset=["spending_to_salary_ratio"]).copy()
gdf_clean = gdf_clean.to_crs(epsg=3824)

# === Шаг 2: Пространственные веса и spatial lag ===
w = Queen.from_dataframe(gdf_clean)
w.transform = 'r'
gdf_clean["spending_to_salary_ratio_lag"] = lag_spatial(
    w, gdf_clean["spending_to_salary_ratio"]
)

# === Шаг 3: Построение карт без ограничения по координатам ===
fig, axes = plt.subplots(1, 2, figsize=(18, 9))

# Оригинал
gdf_clean.plot(
    column="spending_to_salary_ratio",
    cmap="coolwarm",
    legend=True,
    ax=axes[0]
)
axes[0].set_title("Корреляция по соотношению потребления к зарплате")
axes[0].axis("off")

# Spatial lag
gdf_clean.plot(
    column="spending_to_salary_ratio_lag",
    cmap="coolwarm",
    legend=True,
    ax=axes[1]
)
axes[1].set_title("Spatial lag: среднее значение у соседей")
axes[1].axis("off")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ghena\AppData\Local\Temp\ipykernel_12604\332833244.py:11: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w = Queen.from_dataframe(gdf_clean)
# C:\Users\ghena\AppData\Roaming\Python\Python310\site-packages\libpysal\weights\contiguity.py:347: UserWarning: The weights matrix is not fully connected:
#  There are 23 disconnected components.
#  There are 18 islands with ids: 50, 74, 75, 79, 80, 81, 341, 388, 662, 726, 881, 908, 1074, 1526, 1602, 1664, 1700, 1809.
#   W.__init__(self, neighbors, ids=ids, **kw)
# ('WARNING: ', 50, ' is an island (no neighbors)')
# ('WARNING: ', 74, ' is an island (no neighbors)')
# ('WARNING: ', 75, ' is an island (no neighbors)')
# ('WARNING: ', 79, ' is an island (no neighbors)')
# ('WARNING: ', 80, ' is an island (no neighbors)')
# ('WARNING: ', 81, ' is an island (no neighbors)')
# ('WARNING: ', 341, ' is an island (no neighbors)')
# ('WARNING: ', 388, ' is an island (no neighbors)')
# ('WARNING: ', 662, ' is an island (no neighbors)')
# ('WARNING: ', 726, ' is an island (no neighbors)')
# ('WARNING: ', 881, ' is an island (no neighbors)')
# ('WARNING: ', 908, ' is an island (no neighbors)')
# ('WARNING: ', 1074, ' is an island (no neighbors)')
# ('WARNING: ', 1526, ' is an island (no neighbors)')
# ('WARNING: ', 1602, ' is an island (no neighbors)')
# ('WARNING: ', 1664, ' is an island (no neighbors)')
# ('WARNING: ', 1700, ' is an island (no neighbors)')
# ('WARNING: ', 1809, ' is an island (no neighbors)')

# %%
# Классы по квантилям для исходного значения
gdf_clean["ratio_class"] = pd.qcut(gdf_clean["spending_to_salary_ratio"], q=5, labels=False)

# Классы по квантилям для spatial lag
gdf_clean["lag_class"] = pd.qcut(gdf_clean["spending_to_salary_ratio_lag"], q=5, labels=False)

# Сохраняем вместе с классами
gdf_clean.to_file(
    "spending_lag_analysis.gpkg", 
    layer="lag_vs_original_with_classes", 
    driver="GPKG"
)

# %% [markdown]
# "lisa_significant" = true - статистически значимые
# кластеры :
# 1 - Высокое значение и у объекта, и у соседей (кластер)
# 2 - Высокое значение у объекта, но низкое у соседей
# 3 -Низкое значение у объекта, но высокое у соседей
# 4 - Низкое значение и у объекта, и у соседей (кластер)
